# %%
from pycaret.datasets import get_data
data = get_data('juice')
# Out:
#    Id Purchase  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  \
# 0   1       CH             237        1     1.75     1.99    0.00     0.0
# 1   2       CH             239        1     1.75     1.99    0.00     0.3
# 2   3       CH             245        1     1.86     2.09    0.17     0.0
# 3   4       MM             227        1     1.69     1.69    0.00     0.0
# 4   5       CH             228        7     1.69     1.69    0.00     0.0
#
#    SpecialCH  SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff Store7  \
# 0          0          0  0.500000         1.99         1.75       0.24     No
# 1          0          1  0.600000         1.69         1.75      -0.06     No
# 2          0          0  0.680000         2.09         1.69       0.40     No
# 3          0          0  0.400000         1.69         1.69       0.00     No
# 4          0          0  0.956535         1.69         1.69       0.00    Yes
#
#    PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# ...

# %%
from pycaret.classification import *
s = setup(data, target = 'Purchase')
# Out:
# <style  type="text/css" >
# #T_00903a08_b5d1_11eb_818f_5076af549583row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_00903a08_b5d1_11eb_818f_5076af549583" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_00903a08_b5d1_11eb_818f_5076af549583level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_00903a08_b5d1_11eb_818f_5076af549583row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_00903a08_b5d1_11eb_818f_5076af549583row0_col1" class="data row0 col1" >3306</td>
#             </tr>
#             <tr>
#                         <th id="T_00903a08_b5d1_11eb_818f_5076af549583level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
lr = create_model('lr')
# Out:
# <style  type="text/css" >
# #T_089521d4_b5d1_11eb_8238_5076af549583row10_col0,#T_089521d4_b5d1_11eb_8238_5076af549583row10_col1,#T_089521d4_b5d1_11eb_8238_5076af549583row10_col2,#T_089521d4_b5d1_11eb_8238_5076af549583row10_col3,#T_089521d4_b5d1_11eb_8238_5076af549583row10_col4,#T_089521d4_b5d1_11eb_8238_5076af549583row10_col5,#T_089521d4_b5d1_11eb_8238_5076af549583row10_col6{
#             background:  yellow;
#         }</style><table id="T_089521d4_b5d1_11eb_8238_5076af549583" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
plot_model(lr)

# %%
plot_model(lr, plot = 'auc_plotly')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-7decefcffa0a> in <module>
# ----> 1 plot_model(lr, plot = 'auc_plotly')
#
# ~\pycaret-timeseries\pycaret\pycaret\internal\utils.py in wrapper(*args, **kwargs)
#     770                 if globals_d[name] is None:
#     771                     raise ValueError(message)
# --> 772             return func(*args, **kwargs)
#     773
#     774         return wrapper
#
# ~\pycaret-timeseries\pycaret\pycaret\classification.py in plot_model(estimator, plot, scale, save, fold, fit_kwargs, groups, use_train_data, verbose, display_format)
#    1533         verbose=verbose,
#    1534         use_train_data=use_train_data,
# -> 1535         display_format=display_format,
#    1536     )
#    1537
#
# ...
